# %% [markdown]
# # EXTRACTION

# %%
import sqlalchemy #Borrow API/Package/Library for accessing databases in generel 
import mysql #Borrow Driver for accessing mysql DB in specific 

#My local database URL
sanjaydatabaseurl = 'mysql://root:4646@localhost/dvdrental?charset=utf8mb4&binary_prefix=true'
print('estabilishing database connection.inprogress...')
# Out:
# estabilishing database connection.inprogress...

# %%
from sqlalchemy import create_engine #Spend Decide API/Package/Library for accessing databases in generel
engine = create_engine(sanjaydatabaseurl) #Spend Plan API/Package/Library for accessing databases in generel
connection = engine.connect() #Spend the API/money API/Package/Library for accessing databases in generel
connection = connection.execution_options(isolation_level="READ COMMITTED") # just READ

from sqlalchemy.sql import text
MyQuery = text("select * from customer") #Enjoy the be1`nfits of API API/Package/Library for accessing databases in generel
sanjayrows = connection.execute(MyQuery).fetchall() 
print(sanjayrows)
# Out:
# [(1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, 't', '2/14/2006', '49:45.7', 1, '9398730898'), (2, 1, 'Patricia', 'Johnson', 'patricia.johnson@sakilacustomer.org', 6, 't', '2/14/2006', '49:45.7', 1, None), (4, 3, 'Barbara', 'Jones', 'barbara.jones@sakilacustomer.org', 8, 't', '2/14/2006', '49:45.7', 1, None), (5, 1, 'Elizabeth', 'Brown', 'elizabeth.brown@sakilacustomer.org', 9, 't', '2/14/2006', '49:45.7', 1, None), (6, 3, 'Jennifer', 'Davis', 'jennifer.davis@sakilacustomer.org', 10, 't', '2/14/2006', '49:45.7', 1, None), (7, 1, 'Maria', 'Miller', 'maria.miller@sakilacustomer.org', 11, 't', '2/14/2006', '49:45.7', 1, None), (8, 3, 'Susan', 'Wilson', 'susan.wilson@sakilacustomer.org', 12, 't', '2/14/2006', '49:45.7', 1, None), (9, 3, 'Margaret', 'Moore', 'margaret.moore@sakilacustomer.org', 13, 't', '2/14/2006', '49:45.7', 1, None), (10, 1, 'Dorothy', 'Taylor', 'dorothy.taylor@sakilacustomer.org', 14, 't', '2/14/2006', '49:45.7', 0, None), (12, 1, 'Nancy', 'Thomas', 'nancy.thomas@sakilacustomer.org', 16, 't', '2/14/2006', '49:45.7', 0, None), (13, 3, 'Karen', 'Jackson', 'karen.jackson@sakilacustomer.org', 17, 't', '2/14/2006', '49:45.7', 1, None), (14, 3, 'Betty', 'White', 'betty.white@sakilacustomer.org', 18, 't', '2/14/2006', '49:45.7', 1, None), (15, 1, 'Helen', 'Harris', 'helen.harris@sakilacustomer.org', 19, 't', '2/14/2006', '49:45.7', 1, None), (16, 3, 'Sandra', 'Martin', 'sandra.martin@sakilacustomer.org', 20, 't', '2/14/2006', '49:45.7', 0, None), (17, 1, 'Donna', 'Thompson', 'donna.thompson@sakilacustomer.org', 21, 't', '2/14/2006', '49:45.7', 0, None), (18, 3, 'Carol', 'Garcia', 'carol.garcia@sakilacustomer.org', 22, 't', '2/14/2006', '49:45.7', 1, None), (19, 1, 'Ruth', 'Martinez', 'ruth.martinez@sakilacustomer.org', 23, 't', '2/14/2006', '49:45.7', 1, None), (20, 3, 'Sharon', 'Robinson', 'sharon.robinson@sakilacustomer.org', 24, 't', '2/14/2006', '49:45.7', 1, None), (21, 1, 'Michelle', 'Clark', 'michelle.clark@sakilacustomer.org', 25, 't', '2/14/2006', '49:45.7', 1, None), (23, 3, 'Sarah', 'Lewis', 'sarah.lewis@sakilacustomer.org', 27, 't', '2/14/2006', '49:45.7', 1, None), (24, 3, 'Kimberly', 'Lee', 'kimberly.lee@sakilacustomer.org', 28, 't', '2/14/2006', '49:45.7', 1, None), (25, 1, 'Deborah', 'Walker', 'deborah.walker@sakilacustomer.org', 29, 't', '2/14/2006', '49:45.7', 1, None), (26, 3, 'Jessica', 'Hall', 'jessica.hall@sakilacustomer.org', 30, 't', '2/14/2006', '49:45.7', 1, None), (27, 3, 'Shirley', 'Allen', 'shirley.allen@sakilacustomer.org', 31, 't', '2/14/2006', '49:45.7', 1, None), (28, 1, 'Cynthia', 'Young', 'cynthia.young@sakilacustomer.org', 32, 't', '2/14/2006', '49:45.7', 1, None), (29, 3, 'Angela', 'Hernandez', 'angela.hernandez@sakilacustomer.org', 33, 't', '2/14/2006', '49:45.7', 1, None), (30, 1, 'Melissa', 'King', 'melissa.king@sakilacustomer.org', 34, 't', '2/14/2006', '49:45.7', 1, None), (31, 3, 'Brenda', 'Wright', 'brenda.wright@sakilacustomer.org', 35, 't', '2/14/2006', '49:45.7', 1, None), (32, 1, 'Amy', 'Lopez', 'amy.lopez@sakilacustomer.org', 36, 't', '2/14/2006', '49:45.7', 1, None), (33, 3, 'Anna', 'Hill', 'anna.hill@sakilacustomer.org', 37, 't', '2/14/2006', '49:45.7', 1, None), (34, 3, 'Rebecca', 'Scott', 'rebecca.scott@sakilacustomer.org', 38, 't', '2/14/2006', '49:45.7', 1, None), (35, 3, 'Virginia', 'Green', 'virginia.green@sakilacustomer.org', 39, 't', '2/14/2006', '49:45.7', 1, None), (36, 3, 'Kathleen', 'Adams', 'kathleen.adams@sakilacustomer.org', 40, 't', '2/14/2006', '49:45.7', 1, None), (37, 1, 'Pamela', 'Baker', 'pamela.baker@sakilacustomer.org', 41, 't', '2/14/2006', '49:45.7', 1, None), (38, 1, 'Martha', 'Gonzalez', 'martha.gonzalez@sakilacustomer.org', 42, 't', '2/14/2006', '49:45.7', 1, None), (39, 1, 'Debra', 'Nelson', 'debra.nelson@sakilacustomer.org', 43, 't', '2/14/2006', '49:45.7', 1, None), (40, 3, 'Amanda', 'Carter', 'amanda.carter@sakilacustomer.org', 44, 't', '2/14/2006', '49:45.7', 1, None), (41, 1, 'Stephanie', 'Mitchell', 'stephanie.mitchell@s ...

# %%
#type(sanjayrow)

# %%
#for i in range(len(sanjayrow)):
    #print(sanjayrow[i][4])  
    
#import pandas as pd
#df=sanjayrows
#df
import pandas as pd
df = pd.DataFrame(sanjayrows)

#df[[4,5]] brings data for 4th and 5th columns

#df.iloc[:10] #brings data for rows
#df.iloc[:,:5] #brings both rows and columns
df[df[4]=='elizabeth.brown@sakilacustomer.org']# brings data based on a condition

#df.tail(10)
#df.head(5)
#df.columns
# Out:
#    0  1          2      3                                   4  5  6  \
# 3  5  1  Elizabeth  Brown  elizabeth.brown@sakilacustomer.org  9  t
#
#            7        8  9    10
# 3  2/14/2006  49:45.7  1  None

# %%
from sqlalchemy.sql import text
MyQuery1 = text("select * from address") #Enjoy the be1`nfits of API API/Package/Library for accessing databases in generel
sanjayrows1 = connection.execute(MyQuery1).fetchall() 
print(sanjayrows1)
# Out:
# [(1, '47 MySakila Drive', '\\N', 'Gilberta', '300', '', '', datetime.datetime(2006, 2, 15, 9, 45, 30)), (2, '28 MySQL Boulevard', '\\N', 'QLD', '576', '', '', datetime.datetime(2006, 2, 15, 9, 45, 30)), (3, '23 Workhaven Lane', '\\N', 'Alberta', '300', '', '14033335568', datetime.datetime(2006, 2, 15, 9, 45, 30)), (4, '1411 Lillydale Drive', '\\N', 'QLD', '576', '', '6172235589', datetime.datetime(2006, 2, 15, 9, 45, 30)), (5, '1913 Hanoi Way', '', 'Nagasaki', '463', '35200', '28303384290', datetime.datetime(2006, 2, 15, 9, 45, 30)), (6, '1121 Loja Avenue', '', 'California', '449', '17886', '838635286649', datetime.datetime(2006, 2, 15, 9, 45, 30)), (7, '692 Joliet Street', '', 'Attika', '38', '83579', '448477190408', datetime.datetime(2006, 2, 15, 9, 45, 30)), (8, '1566 Inegl Manor', '', 'Mandalay', '349', '53561', '705814003527', datetime.datetime(2006, 2, 15, 9, 45, 30)), (9, '53 Idfu Parkway', '', 'Nantou', '361', '42399', '10655648674', datetime.datetime(2006, 2, 15, 9, 45, 30)), (10, '1795 Santiago de Compostela Way', '', 'Texas', '295', '18743', '860452626434', datetime.datetime(2006, 2, 15, 9, 45, 30)), (11, '900 Santiago de Compostela Parkway', '', 'Central Serbia', '280', '93896', '716571220373', datetime.datetime(2006, 2, 15, 9, 45, 30)), (12, '478 Joliet Way', '', 'Hamilton', '200', '77948', '657282285970', datetime.datetime(2006, 2, 15, 9, 45, 30)), (13, '613 Korolev Drive', '', 'Masqat', '329', '45844', '380657522649', datetime.datetime(2006, 2, 15, 9, 45, 30)), (14, '1531 Sal Drive', '', 'Esfahan', '162', '53628', '648856936185', datetime.datetime(2006, 2, 15, 9, 45, 30)), (15, '1542 Tarlac Parkway', '', 'Kanagawa', '440', '1027', '635297277345', datetime.datetime(2006, 2, 15, 9, 45, 30)), (16, '808 Bhopal Manor', '', 'Haryana', '582', '10672', '465887807014', datetime.datetime(2006, 2, 15, 9, 45, 30)), (17, '270 Amroha Parkway', '', 'Osmaniye', '384', '29610', '695479687538', datetime.datetime(2006, 2, 15, 9, 45, 30)), (18, '770 Bydgoszcz Avenue', '', 'California', '120', '16266', '517338314235', datetime.datetime(2006, 2, 15, 9, 45, 30)), (19, '419 Iligan Lane', '', 'Madhya Pradesh', '76', '72878', '990911107354', datetime.datetime(2006, 2, 15, 9, 45, 30)), (20, '360 Toulouse Parkway', '', 'England', '495', '54308', '949312333307', datetime.datetime(2006, 2, 15, 9, 45, 30)), (21, '270 Toulon Boulevard', '', 'Kalmykia', '156', '81766', '407752414682', datetime.datetime(2006, 2, 15, 9, 45, 30)), (22, '320 Brest Avenue', '', 'Kaduna', '252', '43331', '747791594069', datetime.datetime(2006, 2, 15, 9, 45, 30)), (23, '1417 Lancaster Avenue', '', 'Northern Cape', '267', '72192', '272572357893', datetime.datetime(2006, 2, 15, 9, 45, 30)), (24, '1688 Okara Way', '', 'Nothwest Border Prov', '327', '21954', '144453869132', datetime.datetime(2006, 2, 15, 9, 45, 30)), (25, '262 A Corua (La Corua) Parkway', '', 'Dhaka', '525', '34418', '892775750063', datetime.datetime(2006, 2, 15, 9, 45, 30)), (26, '28 Charlotte Amalie Street', '', 'Rabat-Sal-Zammour-Z', '443', '37551', '161968374323', datetime.datetime(2006, 2, 15, 9, 45, 30)), (27, '1780 Hino Boulevard', '', 'Liepaja', '303', '7716', '902731229323', datetime.datetime(2006, 2, 15, 9, 45, 30)), (28, '96 Tafuna Way', '', 'Crdoba', '128', '99865', '934730187245', datetime.datetime(2006, 2, 15, 9, 45, 30)), (29, '934 San Felipe de Puerto Plata Street', '', 'Sind', '472', '99780', '196495945706', datetime.datetime(2006, 2, 15, 9, 45, 30)), (30, '18 Duisburg Boulevard', '', '', '121', '58327', '998009777982', datetime.datetime(2006, 2, 15, 9, 45, 30)), (31, '217 Botshabelo Place', '', 'Southern Mindanao', '138', '49521', '665356572025', datetime.datetime(2006, 2, 15, 9, 45, 30)), (32, '1425 Shikarpur Manor', '', 'Bihar', '346', '65599', '678220867005', datetime.datetime(2006, 2, 15, 9, 45, 30)), (33, '786 Aurora Avenue', '', 'Yamaguchi', '474', '65750', '18461860151', datetime.datetime(2006, 2, 15, 9, 45, 30)), (34, '1668 Anpolis Street', '', 'Taipei', '316', '50199', '52525554 ...

# %%
#Create Dummy Data

#df_a = pd.DataFrame({
        #'subject_id': ['1', '2', '3', '4', '5'],
        #'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
        #'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']})
        
#df_a = pd.DataFrame(sanjayrows)        
               
#df_b = pd.DataFrame({
        #'subject_id': ['4', '5', '6', '7', '8'],
        #'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
        #'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']})
        
df_b = pd.DataFrame(sanjayrows1)        
               
#df_c = pd.DataFrame({
        #'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        #'test_id': ['51', '15', '15', '61', '16', '14', '15', '1', '61', '16']})
        
#df_c = pd.DataFrame(sanjayrows2)

# %%
#df_a.columns = ['customer_id', 'store_id', 'first_name', 'last_name', 'email', 'address_id', 'active bool', 'create_date', 'lat_update', 'active', 'phone_number']

# %%
df_b.columns = ['address_id', 'address', 'address2', 'district', 'city_id', 'postal_code', 'phone', 'last_update']
df_b.columns
print(df_b)
# Out:
#      address_id                   address address2      district city_id  \
# 0             1         47 MySakila Drive       \N      Gilberta     300
# 1             2        28 MySQL Boulevard       \N           QLD     576
# 2             3         23 Workhaven Lane       \N       Alberta     300
# 3             4      1411 Lillydale Drive       \N           QLD     576
# 4             5            1913 Hanoi Way               Nagasaki     463
# ..          ...                       ...      ...           ...     ...
# 598         601       844 Bucuresti Place               Liaoning     242
# 599         602  1101 Bucuresti Boulevard            West Greece     401
# 600         603    1103 Quilmes Boulevard                  Piura     503
# 601         604       1331 Usak Boulevard                   Vaud     296
# 602         605      1325 Fukuyama Street           Heilongjiang     537
#
#     postal_code         phone         last_update
# 0                             2006-02-15 09:45:30
# 1                             2006-02-15 09:45:30
# 2                 14033335568 2006-02-15 09:45:30
# 3                  6172235589 2006-02-15 09:45:30
# 4         35200   28303384290 2006-02-15 09:45:30
# ..          ...           ...                 ...
# 598       36603  935952366111 2006-02-15 09:45:30
# 599       97661  199514580428 2006-02-15 09:45:30
# 600       52137  644021380889 2006-02-15 09:45:30
# 601       61960  145308717464 2006-02-15 09:45:30
# 602       27107  288241215394 2006-02-15 09:45:30
#
# [603 rows x 8 columns]

# %%
#pd.merge(df_a, df_b, on='address_id', how='inner')
# Out:
#      customer_id  store_id first_name  last_name  \
# 0              1         1       Mary      Smith
# 1              2         1   Patricia    Johnson
# 2              4         3    Barbara      Jones
# 3              5         1  Elizabeth      Brown
# 4              6         3   Jennifer      Davis
# ..           ...       ...        ...        ...
# 559          595         1   Terrence  Gunderson
# 560          596         1    Enrique   Forsythe
# 561          597         1    Freddie     Duggan
# 562          598         1       Wade   Delvalle
# 563          599         3     Austin    Cintron
#
#                                      email  address_id active bool  \
# 0            mary.smith@sakilacustomer.org           5           t
# 1      patricia.johnson@sakilacustomer.org           6           t
# 2         barbara.jones@sakilacustomer.org           8           t
# 3       elizabeth.brown@sakilacustomer.org           9           t
# 4        jennifer.davis@sakilacustomer.org          10           t
# ..                                     ...         ...         ...
# 559  terrence.gunderson@sakilacustomer.org         601           t
# 560    enrique.forsythe@sakilacustomer.org         602           t
# 561      freddie.duggan@sakilacustomer.org         603           t
# 562       wade.delvalle@sakilacustomer.org         604           t
# 563      austin.cintron@sakilacustomer.org         605           t
#
#     create_date lat_update  active phone_number  \
# 0     2/14/2006    49:45.7       1   9398730898
# 1     2/14/2006    49:45.7       1         None
# 2     2/14/2006    49:45.7       1         None
# 3     2/14/2006    49:45.7       1         None
# 4     2/14/2006    49:45.7       1         None
# ..          ...        ...     ...          ...
# 559   2/14/2006    49:45.7       1         None
# 560   2/14/2006    49:45.7       1         None
# 561   2/14/2006    49:45.7       1         None
# 562   2/14/2006    49:45.7       1         None
# 563   2/14/2006    49:45.7       1         None
#
#                              address address2      district city_id  \
# 0                     1913 Hanoi Way               Nagasaki     463
# 1                   1121 Loja Avenue             California     449
# 2                   1566 Inegl Manor               Mandalay     349
# 3                    53 Idfu Parkway                 Nantou     361
# 4    1795 Santiago de Compostela Way                  Texas     295
# ..                               ...      ...           ...     ...
# 559              844 Bucuresti Place               Liaoning     242
# 560         1101 Bucuresti Boulevard            West Greece     401
# 561           1103 Quilmes Boulevard                  Piura     503
# 562              1331 Usak Boulevard                   Vaud     296
# 563             1325 Fukuyama Street           Heilongjiang     537
#
#     postal_code         phone         last_update
# 0         35200   28303384290 2006-02-15 09:45:30
# 1         17886  838635286649 2006-02-15 09:45:30
# 2         53561  705814003527 2006-02-15 09:45:30
# 3         42399   10655648674 2006-02-15 09:45:30
# 4         18743  860452626434 2006-02-15 09:45:30
# ..          ...           ...                 ...
# 559       36603  935952366111 2006-02-15 09:45:30
# 560       97661  199514580428 2006-02-15 09:45:30
# 561       52137  644021380889 2006-02-15 09:45:30
# 562       61960  145308717464 2006-02-15 09:45:30
# 563       27107  288241215394 2006-02-15 09:45:30
#
# [564 rows x 18 columns]

# %%
df_b.apply(lambda x: x)
# Out:
#      address_id                   address address2      district city_id  \
# 0             1         47 MySakila Drive       \N      Gilberta     300
# 1             2        28 MySQL Boulevard       \N           QLD     576
# 2             3         23 Workhaven Lane       \N       Alberta     300
# 3             4      1411 Lillydale Drive       \N           QLD     576
# 4             5            1913 Hanoi Way               Nagasaki     463
# ..          ...                       ...      ...           ...     ...
# 598         601       844 Bucuresti Place               Liaoning     242
# 599         602  1101 Bucuresti Boulevard            West Greece     401
# 600         603    1103 Quilmes Boulevard                  Piura     503
# 601         604       1331 Usak Boulevard                   Vaud     296
# 602         605      1325 Fukuyama Street           Heilongjiang     537
#
#     postal_code         phone         last_update
# 0                             2006-02-15 09:45:30
# 1                             2006-02-15 09:45:30
# 2                 14033335568 2006-02-15 09:45:30
# 3                  6172235589 2006-02-15 09:45:30
# 4         35200   28303384290 2006-02-15 09:45:30
# ..          ...           ...                 ...
# 598       36603  935952366111 2006-02-15 09:45:30
# 599       97661  199514580428 2006-02-15 09:45:30
# 600       52137  644021380889 2006-02-15 09:45:30
# 601       61960  145308717464 2006-02-15 09:45:30
# 602       27107  288241215394 2006-02-15 09:45:30
#
# [603 rows x 8 columns]

# %%
#df_b.apply(lambda x: x[0])
df_b.apply(lambda x: x[0], axis=1)
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 598    601
# 599    602
# 600    603
# 601    604
# 602    605
# Length: 603, dtype: int64

# %%
#for i in range(len(df_b)):

     #print(df_b[i]) #It will not work

# %%
#pd.merge(df_a, df_b, on='address_id', how='right')

# %%
#pd.merge(df_a, df_b, on='address_id', how='left')

# %%
def clip_store_id(store_id):
    if store_id > 1:
        store_id = 3
    return store_id

# %%
df_b["store_id"][ :5]

# %%
def clip_store_id(store_id):
    if store_id > 1:
        store_id = 3
    return store_id
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'store_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-aa961797a5c0> in <module>
#       4     return store_id
#       5
# ----> 6 df_b["store_id"][ :5]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'store_id'

# %% [markdown]
# # LOAD

# %%
import sqlalchemy #Borrow API/Package/Library for accessing databases in general 
import mysql #Borrow Driver for accessing postgres DB in specific 

#My local database URL
sanjaydatabaseurl = 'mysql://root:4646@localhost/dbsanju?charset=utf8mb4&binary_prefix=true'

# %%
#New Fashioned Code
from sqlalchemy import create_engine 
engine = create_engine(sanjaydatabaseurl)
connection = engine.connect() 
connection = connection.execution_options(isolation_level="AUTOCOMMIT") 

from sqlalchemy import Boolean 
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
metadata = MetaData()
Load2table = Table('load2', metadata,
        Column('customer_id', Integer),
        Column('store_id', Integer),
        Column('first_name', String),
        Column('last_name', String),
        Column('email', String),
        Column('address_id', String),
        Column('activebool', String),
        Column('create_date',String),
        Column('last_update',String),
        Column('active',Integer),
        Column('phone_number',String)    )

#This for loop iterates for 564 times
#Assuming i starts with 0
#elizabeth.brown@sakilacustomer.org	 - This value is manually identified as 3rd row 4th column.That means sanjayrows[3][4] 
#print(sanjayrows[3][4]) - just for Testing

for i in range(len(sanjayrows)):
#if(sanjayrows[i][4] === "elizabeth.brown@sakilacustomer.org"):
if(i==4):
ins = Load2table.insert().values(customer_id=sanjayrows[i][0], store_id=sanjayrows[i][1], first_name=sanjayrows[i][2], last_name=sanjayrows[i][3], email=sanjayrows[i][4], address_id=sanjayrows[i][5], activebool=sanjayrows[i][6],create_date=sanjayrows[i][7],last_update=sanjayrows[i][8],active=sanjayrows[i][9],phone_number=sanjayrows[i][10])

    #This is the last step for committing a row
connection.execute(ins)

else:
print("nomatch")
    






connection.close()
# Out:
#   File "<ipython-input-7-9fc5526a44aa>", line 30
#     if(i==4):
#      ^
# IndentationError: expected an indented block
